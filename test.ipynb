# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open("bin.png")

# %%
import cv2

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
BinImage = cv2.imread('bin.png', cv2.IMREAD_GRAYSCALE)

# %%
BinImage=np.zeros([7,7])
BinImage[0:6,0:6]=255

# %%
np.sum(binary_image)
# Out:
# 169634184

# %%
kernel = np.ones((3,3), np.uint8)

# %%
ans=cv2.morphologyEx(BinImage,cv2.MORPH_ERODE,kernel, iterations = 1)

# %%
ans=np.zeros(BinImage.shape)
kernel = np.ones((3,3), np.uint8)
dis=0
while np.sum(BinImage)>0:
    dis=dis+1
    ans=ans+(BinImage-cv2.morphologyEx(BinImage,cv2.MORPH_OPEN,kernel, iterations = 1))//255*dis
    BinImage=cv2.morphologyEx(BinImage,cv2.MORPH_ERODE,kernel, iterations = 1)

# %%
k=image_function.skeleton()

# %%
ans.dtype
# Out:
# dtype('float32')

# %%
gray_image= np.array(image.convert('L'))

# %%
gray_image.shape
# Out:
# (1263, 817)

# %%
gray_image[1:100,1:100].shape
# Out:
# (99, 99)

# %%
testpattern= np.array([
            [0, 0, 1],
            [0, 0, 1],
            [0, 0, 1]
        ], dtype=np.float32)

# %%
out=image_function.dilation_bin(testpattern)

# %%
out
# Out:
# array([[0., 0., 1., 1., 1.],
#        [0., 0., 1., 1., 1.],
#        [0., 0., 1., 1., 1.],
#        [0., 0., 1., 1., 1.],
#        [0., 0., 1., 1., 1.]])

# %%
b_image=image_function.threshold_Otsu(gray_image)
histogram_image=image_function.histogram(gray_image)
convolution_image=image_function.convolutionAndImageFilters(gray_image)
plt.imshow(b_image[0:20,0:20],cmap='gray')
plt.axis('off')
plt.show()

# %%
b2_image=image_function.dilation_bin(b_image)
plt.imshow(b2_image[0:20,0:20],cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.imshow(gray_image,cmap='gray')
plt.axis('off')
plt.show()
